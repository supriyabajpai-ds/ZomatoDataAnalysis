# %% [markdown]
#  __Zomato Restaurant Data Analysis__
#
# This project analyzes restaurant trends.
#
# Dataset
#
# Search Kaggle:
# “Zomato Bangalore Restaurants Dataset”
#
# Questions to answer
#
# Which locations have the most restaurants?
#
# Which cuisines are most popular?
#
# Does rating affect cost?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('BangaloreZomatoData.csv')

# %%
df.head()
# Out:
#                    Name                                                URL  \
# 0        Sri Udupi Park  https://www.zomato.com/bangalore/sri-udupi-par...
# 1         Meghana Foods  https://www.zomato.com/bangalore/meghana-foods...
# 2  Donne Biriyani House  https://www.zomato.com/bangalore/donne-biriyan...
# 3        Domino's Pizza  https://www.zomato.com/bangalore/dominos-pizza...
# 4                   KFC   https://www.zomato.com/bangalore/kfc-indiranagar
#
#                                             Cuisines                    Area  \
# 0  South Indian, North Indian, Chinese, Street Fo...  Indiranagar, Bangalore
# 1             Biryani, Andhra, North Indian, Seafood  Indiranagar, Bangalore
# 2                                            Biryani  Indiranagar, Bangalore
# 3                         Pizza, Fast Food, Desserts  Indiranagar, Bangalore
# 4    Burger, Fast Food, Biryani, Desserts, Beverages  Indiranagar, Bangalore
#
#                          Timing  \
# 0            7am – 11pm (Today)
# 1               Opens at 6:30pm
# 2           11am – 11pm (Today)
# 3  10:57am – 12midnight (Today)
# 4           11am – 11pm (Today)
#
#                                         Full_Address    PhoneNumber  \
# 0  273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 1  544, First Floor, CMH Road, Near Indiranagar M...  +918041135050
# 2  8/ 9, 17th F Cross, 2nd Stage, Indiranagar, Ba...  +918861564169
# 3  308, 2nd Stage, 100 Feet Road, Indiranagar, Ba...  +919916465787
# 4            38/1A, CMH Road, Indiranagar, Bangalore  +919513700040
#
#    IsHomeDelivery  isTakeaway  isIndoorSeating  isVegOnly Dinner Ratings  \
# 0               1           1                1          1            4.0
# 1               1           1                1          0            4.3
# 2               1           1                1          0            3.9
# 3               1           1                1          0            2.4
# 4               1           1                1          0            2.8
#
#    Dinner Reviews Delivery Ratings  Delivery Reviews               KnownFor  \
# 0             462              4.1             16000                    NaN
# 1            1654              4.3             28600  Spicy Chicken Biryani
# 2             411              3.5             33200                    NaN
# 3             422              4.4              8205                    NaN
# 4             673              4.0              9148                    NaN
#
#                                        PopularDishes  \
# 0  Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 1  Authentic Hyderabadi Biryani, Paneer Biryani, ...
# 2                                                NaN
# 3  Barbeque Chicken Pizza, Choco Lava Cake, White...
# 4   Fiery Chicken, Chicken Popcorn, Rice Bowl, Wings
#
#                                       PeopleKnownFor  AverageCost
# 0  Economical, Prompt Service, Hygiene, Quality F...          450
# 1  Boneless Chicken Biryani, Ample Seating Area, ...          700
# 2  Great Recommendations, Nice Taste, Great Ambia...          300
# 3  Value for Money, Packaging, Staff, Ambience, Food          400
# 4  Elegantly Decorated, Great Recommendations, Vi...          400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8923 entries, 0 to 8922
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              8923 non-null   object
#  1   URL               8923 non-null   object
#  2   Cuisines          8923 non-null   object
#  3   Area              8923 non-null   object
#  4   Timing            5820 non-null   object
#  5   Full_Address      8923 non-null   object
#  6   PhoneNumber       8923 non-null   object
#  7   IsHomeDelivery    8923 non-null   int64
#  8   isTakeaway        8923 non-null   int64
#  9   isIndoorSeating   8923 non-null   int64
#  10  isVegOnly         8923 non-null   int64
#  11  Dinner Ratings    8923 non-null   object
#  12  Dinner Reviews    8923 non-null   int64
#  13  Delivery Ratings  8923 non-null   object
#  14  Delivery Reviews  8923 non-null   int64
#  15  KnownFor          258 non-null    object
#  16  PopularDishes     1535 non-null   object
#  17  PeopleKnownFor    3484 non-null   object
#  18  AverageCost       8923 non-null   int64
# dtypes: int64(7), object(12)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (8923, 19)

# %%
df['Full_Address'].head()
# Out:
# 0    273, Monalisa, 6th Main, 100 Feet Road, Indira...
# 1    544, First Floor, CMH Road, Near Indiranagar M...
# 2    8/ 9, 17th F Cross, 2nd Stage, Indiranagar, Ba...
# 3    308, 2nd Stage, 100 Feet Road, Indiranagar, Ba...
# 4              38/1A, CMH Road, Indiranagar, Bangalore
# Name: Full_Address, dtype: object

# %%
def findlocation(text):
    return text.split(",")[-2].strip()

# %% [markdown]
# __EXTRACTING THE NAME OF THE RESTRAUNT__

# %%
df['city']=df['Full_Address'].apply(findlocation)

# %%
df.head()
# Out:
#              Name                                                URL  \
# 0  Sri Udupi Park  https://www.zomato.com/bangalore/sri-udupi-par...
# 0  Sri Udupi Park  https://www.zomato.com/bangalore/sri-udupi-par...
# 0  Sri Udupi Park  https://www.zomato.com/bangalore/sri-udupi-par...
# 0  Sri Udupi Park  https://www.zomato.com/bangalore/sri-udupi-par...
# 0  Sri Udupi Park  https://www.zomato.com/bangalore/sri-udupi-par...
#
#        Cuisines                    Area              Timing  \
# 0  South Indian  Indiranagar, Bangalore  7am – 11pm (Today)
# 0  North Indian  Indiranagar, Bangalore  7am – 11pm (Today)
# 0       Chinese  Indiranagar, Bangalore  7am – 11pm (Today)
# 0   Street Food  Indiranagar, Bangalore  7am – 11pm (Today)
# 0       Biryani  Indiranagar, Bangalore  7am – 11pm (Today)
#
#                                         Full_Address    PhoneNumber  \
# 0  273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 0  273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 0  273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 0  273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 0  273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
#
#    IsHomeDelivery  isTakeaway  isIndoorSeating  ...  Dinner Ratings  \
# 0               1           1                1  ...             4.0
# 0               1           1                1  ...             4.0
# 0               1           1                1  ...             4.0
# 0               1           1                1  ...             4.0
# 0               1           1                1  ...             4.0
#
#    Dinner Reviews  Delivery Ratings  Delivery Reviews  KnownFor  \
# 0             462               4.1             16000       NaN
# 0             462               4.1             16000       NaN
# 0             462               4.1             16000       NaN
# 0             462               4.1             16000       NaN
# 0             462               4.1             16000       NaN
#
#                                        PopularDishes  \
# 0  Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 0  Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 0  Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 0  Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 0  Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
#
#                                       PeopleKnownFor AverageCost         city  \
# 0  Economical, Prompt Service, Hygiene, Quality F...         450  Indiranagar
# 0  Economical, Prompt Service, Hygiene, Quality F...         450  Indiranagar
# 0  Economical, Prompt Service, Hygiene, Quality F...         450  Indiranagar
# 0  Economical, Prompt Service, Hygiene, Quality F...         450  Indiranagar
# 0  Economical, Prompt Service, Hygiene, Quality F...         450  Indiranagar
#
#   Overall Ratings
# 0            4.05
# 0            4.05
# 0            4.05
# 0            4.05
# 0            4.05
#
# [5 rows x 21 columns]

# %%
top_city = df['city'].value_counts().idxmax()
top_city
# Out:
# 'Electronic City'

# %%
s=df['city'].value_counts().head(10)

# %%
sns.countplot(s,gap=0.5)
# Out:
# <Axes: xlabel='city', ylabel='count'>

# %% [markdown]
# __FINDING POPULAR CUISINES__

# %%
s=df['Cuisines'].value_counts

# %%
s
# Out:
# <bound method IndexOpsMixin.value_counts of 0       South Indian, North Indian, Chinese, Street Fo...
# 1                  Biryani, Andhra, North Indian, Seafood
# 2                                                 Biryani
# 3                              Pizza, Fast Food, Desserts
# 4         Burger, Fast Food, Biryani, Desserts, Beverages
#                               ...
# 8918                                            Fast Food
# 8919                      Seafood, Mangalorean, Beverages
# 8920                                       Salad, Chinese
# 8921                                        Thai, Chinese
# 8922                                   Biryani, Fast Food
# Name: Cuisines, Length: 8923, dtype: object>

# %%
#CONVERTING FROM STRING TO FLOAT

# %%
df['Delivery Ratings'] = df['Delivery Ratings'].replace('-',np.nan).astype(float)

# %%
df['Dinner Ratings']=df['Dinner Ratings'].replace('-',np.nan).astype(float)

# %%
df['Delivery Ratings'] = df['Delivery Ratings'].fillna(0.0)
df['Dinner Ratings'] = df['Dinner Ratings'].fillna(0.0)
df['Overall Ratings'] = df[['Delivery Ratings','Dinner Ratings']].mean(axis=1)

# %%
df['Overall Ratings']
# Out:
# 0       4.05
# 0       4.05
# 0       4.05
# 0       4.05
# 0       4.05
#         ...
# 8920    1.85
# 8921    3.65
# 8921    3.65
# 8922    1.95
# 8922    1.95
# Name: Overall Ratings, Length: 28783, dtype: float64

# %%
#SEPERATING THE MULTIPLE CUISINES

# %%
df = df.assign(Cuisines=df['Cuisines'].str.split(', ')).explode('Cuisines')

# %%
df
# Out:
#                        Name  \
# 0            Sri Udupi Park
# 0            Sri Udupi Park
# 0            Sri Udupi Park
# 0            Sri Udupi Park
# 0            Sri Udupi Park
# ...                     ...
# 8920           Bangkok Bowl
# 8921        Yuan Restaurant
# 8921        Yuan Restaurant
# 8922  Amma's Biryani & Rice
# 8922  Amma's Biryani & Rice
#
#                                                     URL      Cuisines  \
# 0     https://www.zomato.com/bangalore/sri-udupi-par...  South Indian
# 0     https://www.zomato.com/bangalore/sri-udupi-par...  North Indian
# 0     https://www.zomato.com/bangalore/sri-udupi-par...       Chinese
# 0     https://www.zomato.com/bangalore/sri-udupi-par...   Street Food
# 0     https://www.zomato.com/bangalore/sri-udupi-par...       Biryani
# ...                                                 ...           ...
# 8920  https://www.zomato.com/bangalore/bangkok-bowl-...       Chinese
# 8921  https://www.zomato.com/bangalore/yuan-restaura...          Thai
# 8921  https://www.zomato.com/bangalore/yuan-restaura...       Chinese
# 8922  https://www.zomato.com/bangalore/ammas-biryani...       Biryani
# 8922  https://www.zomato.com/bangalore/ammas-biryani...     Fast Food
#
#                          Area                               Timing  \
# 0      Indiranagar, Bangalore                   7am – 11pm (Today)
# 0      Indiranagar, Bangalore                   7am – 11pm (Today)
# 0      Indiranagar, Bangalore                   7am – 11pm (Today)
# 0      Indiranagar, Bangalore                   7am – 11pm (Today)
# 0      Indiranagar, Bangalore                   7am – 11pm (Today)
# ...                       ...                                  ...
# 8920  Kammanahalli, Bangalore  12noon – 3pm, 6:30pm – 10pm (Today)
# 8921    HBR Layout, Bangalore                         Opens at 7pm
# 8921    HBR Layout, Bangalore                         Opens at 7pm
# 8922  Kammanahalli, Bangalore            11:30am – 11:30pm (Today)
# 8922  Kammanahalli, Bangalore            11:30am – 11:30pm (Today)
#
#                                            Full_Address    PhoneNumber  \
# 0     273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 0     273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 0     273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 0     273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# 0     273, Monalisa, 6th Main, 100 Feet Road, Indira...  +919945977774
# ...                                                 ...            ...
# 8920  403, 3A Cross, Mariayappa Road, Kammanahalli, ...  +919739999170
# 8921  2&3, Renu Arcade, 1st Stage, 2nd Block, 80 Fee...  +919901047070
# 8921  2&3, Renu Arcade, 1st Stage, 2nd Block, 80 Fee...  +919901047070
# 8922  21, Ground Floor, Praise The Lord Mansion, Neh...  +917349446837
# 8922  21, Ground Floor, Praise The Lord Mansion, Neh...  +917349446837
#
#       IsHomeDelivery  isTakeaway  isIndoorSeating  ...  Dinner Ratings  \
# 0                  1           1                1  ...             4.0
# 0                  1           1                1  ...             4.0
# 0                  1           1                1  ...             4.0
# 0                  1           1                1  ...             4.0
# 0                  1           1                1  ...             4.0
# ...              ...         ...              ...  ...             ...
# 8920               1           1                0  ...             0.0
# 8921               1           1                1  ...             3.8
# 8921               1           1                1  ...             3.8
# 8922               1           1                1  ...             3.9
# 8922               1           1                1  ...             3.9
#
#       Dinner Reviews  Delivery Ratings  Delivery Reviews  KnownFor  \
# 0                462               4.1             16000       NaN
# 0                462               4.1             16000       NaN
# 0                462               4.1             16000       NaN
# 0                462               4.1             16000       NaN
# 0                462               4.1             16000       NaN
# ...              ...               ...               ...       ...
# 8920               0               3.7               254       NaN
# 8921             188               3.5              3169       NaN
# 8921             188               3.5              3169       NaN
# 8922               6               0.0                18       NaN
# 8922               6               0.0                18       NaN
#
#                                           PopularDishes  \
# 0     Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 0     Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 0     Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 0     Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# 0     Filtered Coffee, Sambhar, Pav Bhaji, Gobi Manc...
# ...                                                 ...
# 8920                                                NaN
# 8921                                                NaN
# 8921                                                NaN
# 8922                                                NaN
# 8922                                                NaN
#
#                                          PeopleKnownFor AverageCost  \
# 0     Economical, Prompt Service, Hygiene, Quality F...         450
# 0     Economical, Prompt Service, Hygiene, Quality F...         450
# 0     Economical, Prompt Service, Hygiene, Quality F...         450
# 0     Economical, Prompt Service, Hygiene, Quality F...         450
# 0     Economical, Prompt Service, Hygiene, Quality F...         450
# ...                                                 ...         ...
# 8920  Contactless Delivery, Portion, Great Portions,...         300
# 8921  Calm, Prompt Service, Portions, Spicy, Delicio...         400
# 8921  Calm, Prompt Service, Portions, Spicy, Delicio...         400
# 8922                                                NaN         300
# 8922                                                NaN         300
#
#               city Overall Ratings
# 0      Indiranagar            4.05
# 0      Indiranagar            4.05
# 0      Indiranagar            4.05
# 0      Indiranagar            4.05
# 0      Indiranagar            4.05
# ...            ...             ...
# 8920  Kammanahalli            1.85
# 8921    HBR Layout            3.65
# 8921    HBR Layout            3.65
# 8922  Kammanahalli            1.95
# 8922  Kammanahalli            1.95
#
# [28783 rows x 21 columns]

# %%
#INSIGHT-Most restaurants are rated between 3 and 4.5

# %%
t=df.groupby('Cuisines')['Overall Ratings'].mean().sort_values(ascending=False)

# %%
t.head(10)
# Out:
# Cuisines
# Nepalese       4.300
# Malaysian      4.200
# African        4.150
# Assamese       4.150
# Cantonese      4.050
# Singaporean    4.040
# Iranian        3.950
# British        3.925
# Konkan         3.875
# Parsi          3.875
# Name: Overall Ratings, dtype: float64

# %%
top_cuisines = df.groupby('Cuisines')['Overall Ratings'].mean().sort_values(ascending=False).head(10)

sns.barplot(x=top_cuisines.values, y=top_cuisines.index)
plt.title("Top 10 Cuisines by Average Rating")
plt.xlabel("Average Rating")
plt.ylabel("Cuisine")
# Out:
# Text(0, 0.5, 'Cuisine')

# %% [markdown]
# __RATINGS AFFECT COST__

# %%
t=df.groupby('Overall Ratings')['AverageCost'].mean().sort_values(ascending=False)

# %%
t=pd.DataFrame(t)

# %%
sns.boxplot(
    x=df['Overall Ratings'].round(1),
    y=df['AverageCost']
)
# Out:
# <Axes: xlabel='Overall Ratings', ylabel='AverageCost'>

# %%
plt.figure(figsize=(8,6))

corr = df[['Delivery Ratings','Dinner Ratings','Overall Ratings','AverageCost']].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Between Ratings and Cost")
plt.show()

# %%
sns.pairplot(df[['Delivery Ratings','Dinner Ratings','Overall Ratings','AverageCost']])

# %% [markdown]
# SHOWS HOW FACTORS LIKE DELVIERY RATING AND ALL EFFECT COST
#
#
# _Insight_
#
#
# #Higher rated restaurants generally tend to have higher average costs.

# %% [markdown]
# __FEW VISUALIZATIONS__

# %%
#Distribution of Restaurant Ratings

# %%
sns.histplot(df['Overall Ratings'], bins=20)
plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Rating")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#This histogram shows the distribution of restaurant ratings in the dataset.
#Most restaurants have ratings between 3.0 and 4.5 -indicating that the majority of restaurants are moderately to highly rated.

# %%
#Cost Distribution of Restaurants

# %%
sns.histplot(df['AverageCost'], bins=30)
plt.title("Distribution of Average Restaurant Cost")
plt.xlabel("Average Cost")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Cost Distribution by Rating (Boxplot)

# %%
#THANK YOU
